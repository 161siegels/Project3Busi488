# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df_accepted = pd.read_csv("accepted_2007_to_2018Q4.csv")
# df_rejected = pd.read_csv("rejected.csv")
# Out:
# /Users/carterpace/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(df_accepted.info())
# print(df_rejected.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), object(38)
# memory usage: 2.5+ GB
# None

# %%
df_accepted.loan_status.value_counts()
# Out:
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: loan_status, dtype: int64

# %%
df = df_accepted[df_accepted['loan_status'].isin(['Fully Paid', 'Charged Off', 'Default'])]

# %%
# dummy variable to include Default in Charged Off
# df['bad_loan'] =

# %%
df['year'] = df['issue_d'].str.strip().str[-4:]
# Out:
# /Users/carterpace/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.year.value_counts()
# Out:
# 2015    375546
# 2016    293105
# 2014    223103
# 2017    169321
# 2013    134804
# 2018     56318
# 2012     53367
# 2011     21721
# 2010     11536
# 2009      4716
# 2008      1562
# 2007       251
# Name: year, dtype: int64

# %%
df = df[df['year'].isin(['2014', '2015', '2016', '2017', '2018'])]

# %%
df.shape
# Out:
# (1117393, 152)

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_last_payment_amount', 'disbursement_method',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term', 'year'],
#       dtype='object', length=152)

# %%
total_num = df.isnull().sum().sort_values(ascending=False)

# %%
perc = df.isnull().sum()/df.isnull().count() *100
perc1 = (round(perc,2).sort_values(ascending=False))

# Creating a data frame:
df_miss = pd.concat([total_num, perc1], axis =1 , keys =["Total Missing Values", "Percentage %"]).sort_values(by ="Percentage %", ascending = False)
# Out:
# /Users/carterpace/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """

# %%
top_mis = df_miss[df_miss["Percentage %"]<10]
top_mis.reset_index(inplace=True)
vals = list(top_mis['index'])

# %%
df = df[vals]

# %%
df.shape
# Out:
# (1117393, 94)

# %%
num_feat = df.select_dtypes('number').columns.values
df[num_feat].nunique().sort_values()
# Out:
# policy_code                         1
# num_tl_30dpd                        5
# num_tl_120dpd_2m                    6
# inq_last_6mths                      7
# acc_now_delinq                      8
# chargeoff_within_12_mths           11
# pub_rec_bankruptcies               12
# collections_12_mths_ex_med         15
# mths_since_recent_inq              26
# num_tl_90g_dpd_24m                 28
# delinq_2yrs                        30
# num_tl_op_past_12m                 32
# num_actv_bc_tl                     34
# tax_liens                          34
# pub_rec                            36
# fico_range_low                     38
# fico_range_high                    38
# num_accts_ever_120_pd              39
# mort_acc                           39
# out_prncp_inv                      41
# out_prncp                          41
# num_rev_tl_bal_gt_0                46
# num_actv_rev_tl                    52
# num_bc_sats                        52
# acc_open_past_24mths               55
# num_bc_tl                          67
# last_fico_range_low                71
# last_fico_range_high               72
# num_op_rev_tl                      74
# num_sats                           83
#                                ...
# mo_sin_old_il_acct                519
# pct_tl_nvr_dlq                    626
# mo_sin_old_rev_tl_op              753
# revol_util                       1280
# bc_util                          1429
# funded_amnt                      1549
# loan_amnt                        1549
# funded_amnt_inv                  1565
# delinq_amnt                      1888
# dti                              7067
# total_bc_limit                   8411
# total_rec_late_fee              11588
# tot_coll_amt                    12679
# total_rev_hi_lim                19232
# annual_inc                      55775
# bc_open_to_buy                  72866
# avg_cur_bal                     74354
# installment                     75388
# revol_bal                       80339
# recoveries                     114693
# collection_recovery_fee        125304
# total_il_high_credit_limit     158630
# total_bal_ex_mort              173333
# total_rec_prncp                176329
# tot_cur_bal                    380485
# tot_hi_cred_lim                405183
# total_rec_int                  464335
# last_pymnt_amnt                615096
# total_pymnt_inv                878429
# total_pymnt                   1047106
# Length: 69, dtype: int64

# %%
import numpy as np
from itertools import combinations
from scipy.stats import pearsonr

num_feat = df.select_dtypes('number').columns.values
comb_num_feat = np.array(list(combinations(num_feat, 2)))
corr_num_feat = np.array([])
for comb in comb_num_feat:
    corr = pearsonr(df[comb[0]], df[comb[1]])[0]
#     corr = pearsonr(df.dropna()[comb[0]], df.dropna()[comb[1]])[0]
    corr_num_feat = np.append(corr_num_feat, corr)
# Out:
# /Users/carterpace/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:3010: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
corr_num_feat
# Out:
# array([       nan,        nan,        nan, ..., 0.51269767, 0.04609503,
#        0.25066582])

# %%
high_corr_num = comb_num_feat[np.abs(corr_num_feat) >= 0.8]
high_corr_num
# Out:
# /Users/carterpace/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater_equal
#   """Entry point for launching an IPython kernel.
# array([['revol_bal', 'total_rev_hi_lim'],
#        ['recoveries', 'collection_recovery_fee'],
#        ['total_pymnt_inv', 'total_rec_prncp'],
#        ['total_pymnt_inv', 'total_pymnt'],
#        ['total_pymnt_inv', 'installment'],
#        ['total_pymnt_inv', 'funded_amnt_inv'],
#        ['total_pymnt_inv', 'funded_amnt'],
#        ['total_pymnt_inv', 'loan_amnt'],
#        ['total_rec_prncp', 'total_pymnt'],
#        ['total_pymnt', 'installment'],
#        ['total_pymnt', 'funded_amnt_inv'],
#        ['total_pymnt', 'funded_amnt'],
#        ['total_pymnt', 'loan_amnt'],
#        ['total_il_high_credit_limit', 'total_bal_ex_mort'],
#        ['tot_hi_cred_lim', 'tot_cur_bal'],
#        ['num_actv_bc_tl', 'num_bc_sats'],
#        ['num_actv_bc_tl', 'num_rev_tl_bal_gt_0'],
#        ['num_actv_bc_tl', 'num_actv_rev_tl'],
#        ['out_prncp_inv', 'out_prncp'],
#        ['installment', 'funded_amnt_inv'],
#        ['installment', 'funded_amnt'],
#        ['installment', 'loan_amnt'],
#        ['funded_amnt_inv', 'funded_amnt'],
#        ['funded_amnt_inv', 'loan_amnt'],
#        ['funded_amnt', 'loan_amnt'],
#        ['fico_range_low', 'fico_range_high'],
#        ['open_acc', 'num_sats'],
#        ['open_acc', 'num_op_rev_tl'],
#        ['num_sats', 'num_op_rev_tl'],
#        ['num_rev_tl_bal_gt_0', 'num_actv_rev_tl'],
#        ['last_fico_range_high', 'last_fico_range_low']], dtype='<U26')

# %%
df3 = df.drop(np.unique(high_corr_num[:, 0]), axis=1, errors='ignore')
df3.shape
# Out:
# (1117393, 77)

# %%
df3.head()
# Out:
#    mths_since_recent_inq             emp_title emp_length  num_tl_120dpd_2m  \
# 0                    4.0               leadman  10+ years               0.0
# 1                    0.0              Engineer  10+ years               0.0
# 2                   10.0          truck driver  10+ years               0.0
# 4                    1.0   Contract Specialist    3 years               0.0
# 5                    NaN  Veterinary Tecnician    4 years               0.0
#
#    mo_sin_old_il_acct               title  bc_util  percent_bc_gt_75  \
# 0               148.0  Debt consolidation     37.2               0.0
# 1               113.0            Business     27.1               7.7
# 2               125.0                 NaN     55.9              50.0
# 4               128.0      Major purchase     77.5              60.0
# 5               338.0  Debt consolidation     91.0             100.0
#
#    bc_open_to_buy  mths_since_recent_bc   ...    num_accts_ever_120_pd  \
# 0          1506.0                   4.0   ...                      2.0
# 1         57830.0                   2.0   ...                      0.0
# 2          2737.0                 101.0   ...                      0.0
# 4          4567.0                   4.0   ...                      0.0
# 5           844.0                  36.0   ...                      0.0
#
#    mort_acc  mo_sin_rcnt_tl mo_sin_rcnt_rev_tl_op  mo_sin_old_rev_tl_op  \
# 0       1.0             3.0                   3.0                 128.0
# 1       4.0             2.0                   2.0                 192.0
# 2       5.0            14.0                  14.0                 184.0
# 4       6.0             4.0                   4.0                 210.0
# 5       0.0            32.0                  32.0                  54.0
#
#    loan_status  loan_amnt last_pymnt_amnt  last_fico_range_low zip_code
# 0   Fully Paid     3600.0          122.67                560.0    190xx
# 1   Fully Paid    24700.0          926.35                695.0    577xx
# 2   Fully Paid    20000.0        15813.30                700.0    605xx
# 4   Fully Paid    10400.0        10128.96                700.0    174xx
# 5   Fully Paid    11950.0         7653.56                755.0    300xx
#
# [5 rows x 77 columns]

# %%
# df3.info()
df3['loan_status'].value_counts()
# Out:
# Fully Paid     884132
# Charged Off    233221
# Default            40
# Name: loan_status, dtype: int64

# %%
# df3.drop(['emp_title', ])
df4 = df3.select_dtypes(include='object')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1117393 entries, 0 to 2260697
# Data columns (total 25 columns):
# emp_title               1045806 non-null object
# emp_length              1047842 non-null object
# title                   1100752 non-null object
# last_pymnt_d            1115301 non-null object
# pymnt_plan              1117393 non-null object
# purpose                 1117393 non-null object
# sub_grade               1117393 non-null object
# year                    1117393 non-null object
# verification_status     1117393 non-null object
# url                     1117393 non-null object
# term                    1117393 non-null object
# initial_list_status     1117393 non-null object
# id                      1117393 non-null object
# home_ownership          1117393 non-null object
# hardship_flag           1117393 non-null object
# grade                   1117393 non-null object
# earliest_cr_line        1117393 non-null object
# disbursement_method     1117393 non-null object
# debt_settlement_flag    1117393 non-null object
# application_type        1117393 non-null object
# addr_state              1117393 non-null object
# issue_d                 1117393 non-null object
# last_credit_pull_d      1117350 non-null object
# loan_status             1117393 non-null object
# zip_code                1117392 non-null object
# dtypes: object(25)
# memory usage: 221.7+ MB

# %%
# MAYBE FEATURE ENGINEER REGION FROM "ADDR_STATE"
# - create interest rate factor type variable

# %%
drop_col = ['emp_title', 
            'title', 
            'last_pymnt_d', 
            'pymnt_plan', 
            'url', 
            'id', 
            'hardship_flag', 
            'grade', 
            'earliest_cr_line', 
            'year', 
            'last_credit_pull_d', 
            'zip_code',
            
            ##numeral variables
            'last_fico_range_low',
            'last_pymnt_amnt',
            ]

# %%
df3 = df3.drop(drop_col, axis=1)

# %%
df3.shape
# Out:
# (1117393, 63)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1117393 entries, 0 to 2260697
# Data columns (total 63 columns):
# mths_since_recent_inq         1010973 non-null float64
# emp_length                    1047842 non-null object
# num_tl_120dpd_2m              1067773 non-null float64
# mo_sin_old_il_acct            1085475 non-null float64
# bc_util                       1104377 non-null float64
# percent_bc_gt_75              1104650 non-null float64
# bc_open_to_buy                1105059 non-null float64
# mths_since_recent_bc          1105784 non-null float64
# revol_util                    1116711 non-null float64
# dti                           1117019 non-null float64
# policy_code                   1117393 non-null float64
# pub_rec                       1117393 non-null float64
# pub_rec_bankruptcies          1117393 non-null float64
# purpose                       1117393 non-null object
# acc_now_delinq                1117393 non-null float64
# sub_grade                     1117393 non-null object
# tax_liens                     1117393 non-null float64
# verification_status           1117393 non-null object
# total_rev_hi_lim              1117393 non-null float64
# total_rec_late_fee            1117393 non-null float64
# total_rec_int                 1117393 non-null float64
# term                          1117393 non-null object
# total_bc_limit                1117393 non-null float64
# total_bal_ex_mort             1117393 non-null float64
# total_acc                     1117393 non-null float64
# tot_cur_bal                   1117393 non-null float64
# tot_coll_amt                  1117393 non-null float64
# pct_tl_nvr_dlq                1117392 non-null float64
# out_prncp                     1117393 non-null float64
# inq_last_6mths                1117392 non-null float64
# initial_list_status           1117393 non-null object
# home_ownership                1117393 non-null object
# fico_range_high               1117393 non-null float64
# disbursement_method           1117393 non-null object
# delinq_amnt                   1117393 non-null float64
# delinq_2yrs                   1117393 non-null float64
# debt_settlement_flag          1117393 non-null object
# collections_12_mths_ex_med    1117393 non-null float64
# collection_recovery_fee       1117393 non-null float64
# chargeoff_within_12_mths      1117393 non-null float64
# avg_cur_bal                   1117377 non-null float64
# application_type              1117393 non-null object
# annual_inc                    1117393 non-null float64
# addr_state                    1117393 non-null object
# int_rate                      1117393 non-null float64
# issue_d                       1117393 non-null object
# num_bc_sats                   1117393 non-null float64
# num_tl_op_past_12m            1117393 non-null float64
# num_tl_90g_dpd_24m            1117393 non-null float64
# num_tl_30dpd                  1117393 non-null float64
# num_rev_accts                 1117392 non-null float64
# num_op_rev_tl                 1117393 non-null float64
# num_il_tl                     1117393 non-null float64
# num_bc_tl                     1117393 non-null float64
# num_actv_rev_tl               1117393 non-null float64
# acc_open_past_24mths          1117393 non-null float64
# num_accts_ever_120_pd         1117393 non-null float64
# mort_acc                      1117393 non-null float64
# mo_sin_rcnt_tl                1117393 non-null float64
# mo_sin_rcnt_rev_tl_op         1117393 non-null float64
# mo_sin_old_rev_tl_op          1117393 non-null float64
# loan_status                   1117393 non-null object
# loan_amnt                     1117393 non-null float64
# dtypes: float64(50), object(13)
# memory usage: 545.6+ MB

# %%
# df4['num_tl_120dpd_2m'].value_counts()

# %%
df4 = df3.select_dtypes(include='object')
categorical_features = list(df4.columns)

# %%
#categories
for col in categorical_features:
        df3[col] = df3[col].astype('category')

# %%
df3['policy_code'] = df3['policy_code'].astype('category')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1117393 entries, 0 to 2260697
# Data columns (total 63 columns):
# mths_since_recent_inq         1010973 non-null float64
# emp_length                    1047842 non-null category
# num_tl_120dpd_2m              1067773 non-null float64
# mo_sin_old_il_acct            1085475 non-null float64
# bc_util                       1104377 non-null float64
# percent_bc_gt_75              1104650 non-null float64
# bc_open_to_buy                1105059 non-null float64
# mths_since_recent_bc          1105784 non-null float64
# revol_util                    1116711 non-null float64
# dti                           1117019 non-null float64
# policy_code                   1117393 non-null category
# pub_rec                       1117393 non-null float64
# pub_rec_bankruptcies          1117393 non-null float64
# purpose                       1117393 non-null category
# acc_now_delinq                1117393 non-null float64
# sub_grade                     1117393 non-null category
# tax_liens                     1117393 non-null float64
# verification_status           1117393 non-null category
# total_rev_hi_lim              1117393 non-null float64
# total_rec_late_fee            1117393 non-null float64
# total_rec_int                 1117393 non-null float64
# term                          1117393 non-null category
# total_bc_limit                1117393 non-null float64
# total_bal_ex_mort             1117393 non-null float64
# total_acc                     1117393 non-null float64
# tot_cur_bal                   1117393 non-null float64
# tot_coll_amt                  1117393 non-null float64
# pct_tl_nvr_dlq                1117392 non-null float64
# out_prncp                     1117393 non-null float64
# inq_last_6mths                1117392 non-null float64
# initial_list_status           1117393 non-null category
# home_ownership                1117393 non-null category
# fico_range_high               1117393 non-null float64
# disbursement_method           1117393 non-null category
# delinq_amnt                   1117393 non-null float64
# delinq_2yrs                   1117393 non-null float64
# debt_settlement_flag          1117393 non-null category
# collections_12_mths_ex_med    1117393 non-null float64
# collection_recovery_fee       1117393 non-null float64
# chargeoff_within_12_mths      1117393 non-null float64
# avg_cur_bal                   1117377 non-null float64
# application_type              1117393 non-null category
# annual_inc                    1117393 non-null float64
# addr_state                    1117393 non-null category
# int_rate                      1117393 non-null float64
# issue_d                       1117393 non-null category
# num_bc_sats                   1117393 non-null float64
# num_tl_op_past_12m            1117393 non-null float64
# num_tl_90g_dpd_24m            1117393 non-null float64
# num_tl_30dpd                  1117393 non-null float64
# num_rev_accts                 1117392 non-null float64
# num_op_rev_tl                 1117393 non-null float64
# num_il_tl                     1117393 non-null float64
# num_bc_tl                     1117393 non-null float64
# num_actv_rev_tl               1117393 non-null float64
# acc_open_past_24mths          1117393 non-null float64
# num_accts_ever_120_pd         1117393 non-null float64
# mort_acc                      1117393 non-null float64
# mo_sin_rcnt_tl                1117393 non-null float64
# mo_sin_rcnt_rev_tl_op         1117393 non-null float64
# mo_sin_old_rev_tl_op          1117393 non-null float64
# loan_status                   1117393 non-null category
# loan_amnt                     1117393 non-null float64
# dtypes: category(14), float64(49)
# memory usage: 441.2 MB

# %%
libor = pd.read_csv('libor.csv')
libor.head()
# Out:
#       month  libor
# 0  Jan-2020   1.66
# 1  Dec-2019   1.76
# 2  Nov-2019   1.69
# 3  Oct-2019   1.79
# 4  Sep-2019   2.02

# %%
df3['issue_d'] = df3['issue_d'].astype('object')
df123 = pd.merge(df3, libor, left_on='issue_d', right_on='month')
df123.head()
# Out:
#    mths_since_recent_inq emp_length  num_tl_120dpd_2m  mo_sin_old_il_acct  \
# 0                    4.0  10+ years               0.0               148.0
# 1                    0.0  10+ years               0.0               113.0
# 2                   10.0  10+ years               0.0               125.0
# 3                    1.0    3 years               0.0               128.0
# 4                    NaN    4 years               0.0               338.0
#
#    bc_util  percent_bc_gt_75  bc_open_to_buy  mths_since_recent_bc  \
# 0     37.2               0.0          1506.0                   4.0
# 1     27.1               7.7         57830.0                   2.0
# 2     55.9              50.0          2737.0                 101.0
# 3     77.5              60.0          4567.0                   4.0
# 4     91.0             100.0           844.0                  36.0
#
#    revol_util    dti  ...   acc_open_past_24mths  num_accts_ever_120_pd  \
# 0        29.7   5.91  ...                    4.0                    2.0
# 1        19.2  16.06  ...                    4.0                    0.0
# 2        56.2  10.78  ...                    6.0                    0.0
# 3        64.5  25.37  ...                   10.0                    0.0
# 4        68.4  10.20  ...                    0.0                    0.0
#
#    mort_acc mo_sin_rcnt_tl  mo_sin_rcnt_rev_tl_op mo_sin_old_rev_tl_op  \
# 0       1.0            3.0                    3.0                128.0
# 1       4.0            2.0                    2.0                192.0
# 2       5.0           14.0                   14.0                184.0
# 3       6.0            4.0                    4.0                210.0
# 4       0.0           32.0                   32.0                 54.0
#
#    loan_status loan_amnt     month  libor
# 0   Fully Paid    3600.0  Dec-2015   0.42
# 1   Fully Paid   24700.0  Dec-2015   0.42
# 2   Fully Paid   20000.0  Dec-2015   0.42
# 3   Fully Paid   10400.0  Dec-2015   0.42
# 4   Fully Paid   11950.0  Dec-2015   0.42
#
# [5 rows x 65 columns]

# %%
df123 = df123.drop('month', axis=1)
df123.shape
# Out:
# (1117393, 64)

# %%
numeric_features = df123.select_dtypes(include=['int64', 'float64']).columns
categorical_features = df123.select_dtypes(include=['object', 'category']).columns
categorical_features=categorical_features.drop(['loan_status'])

# print(numeric_features)

# %%
# # imputing

# #6 You need to import an imputer, for instance the Imputer from sklearn
# from sklearn.impute import SimpleImputer

# #6a Now you need to impute missing numerical values. What imputation strategy will you choose?
# imputer = SimpleImputer(missing_values = np.nan, strategy = 'median')
# imputer = imputer.fit(df123[numeric_features.tolist()])
# df123[numeric_features.tolist()] = imputer.transform(df123[numeric_features.tolist()])

# #new
# imputercat = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
# df123[categorical_features] = imputercat.fit_transform(df123[categorical_features.tolist()])

# #6d Check if you resolved all missing values
# print(df123.isnull().sum())

# %%
# df123['int_rate_over_libor'] = df123['int_rate']/(df123['libor'])
# df123[['issue_d', 'int_rate', 'libor', 'int_rate_over_libor']]

# %%
#dropped these two because too many unique values. Maybe we can feature engineer them down.
df123 = df123.drop(['issue_d','addr_state'], axis=1)
data=df123.copy().sample(n=50000, random_state=1)
numeric_features = data.select_dtypes(include=['int64', 'float64']).columns
categorical_features = data.select_dtypes(include=['object', 'category']).columns
categorical_features=categorical_features.drop(['loan_status'])
X = data.loc[:, data.columns != 'loan_status']
# Create a new dataframe y that includes only our 
y = data.loan_status

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer


#1 Inner Pipeline1: Create a numeric transformer with 2 steps
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy = 'median'))])

#2 Inner Pipeline2: Create a categorical transformer with 2 steps
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(drop='first'))])

#3 Create Preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.feature_selection import SelectFromModel, SelectKBest
from matplotlib import pyplot as plt
MainPipe = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(n_estimators=90) )])
#('fs',SelectFromModel(ExtraTreesClassifier())),
# split sample into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y,random_state=42)  # random_state=21 # stratify=y


# Fit Model
MainPipe.fit(X_train,y_train)

# Predict model
y_pred = MainPipe.predict(X_test)

# Output the accuracy of our prediction
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

# Visualize the confusion matrix to make it easier to read
from sklearn.metrics import confusion_matrix
con_matrix = confusion_matrix(y_test, y_pred)
confusion_matrix_df = pd.DataFrame(con_matrix, ('0', '1'), ('0', '1'))
heatmap = sns.heatmap(confusion_matrix_df, annot=True, annot_kws={"size": 20}, fmt="d", cmap="Blues")
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize = 14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize = 14)
plt.ylabel('Actual', fontsize = 14)
plt.xlabel('Predicted', fontsize = 14)

# Print the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# 0.9286666666666666
#               precision    recall  f1-score   support
#
#  Charged Off       1.00      0.66      0.79      3104
#   Fully Paid       0.92      1.00      0.96     11896
#
#     accuracy                           0.93     15000
#    macro avg       0.96      0.83      0.87     15000
# weighted avg       0.93      0.93      0.92     15000

# %%
mult_value=[]
for col in pd.get_dummies(X_train,drop_first=True):
    mult_value.append(len(pd.get_dummies(X_train,drop_first=True)[col].unique())!=1)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a pd.Series of features importances
importances_rf = pd.Series(MainPipe.named_steps['classifier'].feature_importances_, 
                           index = pd.get_dummies(X,drop_first=True).drop(['home_ownership_NONE','purpose_educational'],axis=1).columns)

# Sort importances_rf
sorted_importances_rf = importances_rf.sort_values()

# Make a horizontal bar plot
plt.figure(figsize=(15,10))
sorted_importances_rf.plot(kind='barh', color='skyblue'); 
plt.show()

# %%
sorted_importances_rf[-30:].index.tolist()
# Out:
# ['num_bc_tl',
#  'acc_open_past_24mths',
#  'mo_sin_rcnt_tl',
#  'mths_since_recent_inq',
#  'mo_sin_rcnt_rev_tl_op',
#  'num_il_tl',
#  'num_rev_accts',
#  'total_acc',
#  'fico_range_high',
#  'mths_since_recent_bc',
#  'libor',
#  'verification_status_Verified',
#  'total_rev_hi_lim',
#  'total_bc_limit',
#  'total_bal_ex_mort',
#  'loan_amnt',
#  'bc_util',
#  'revol_util',
#  'bc_open_to_buy',
#  'mo_sin_old_il_acct',
#  'annual_inc',
#  'tot_cur_bal',
#  'avg_cur_bal',
#  'mo_sin_old_rev_tl_op',
#  'dti',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'int_rate',
#  'debt_settlement_flag_Y',
#  'collection_recovery_fee']

# %%
drop_vars = [
 'num_op_rev_tl',
 'acc_open_past_24mths',
 'mo_sin_rcnt_tl',
 'mths_since_recent_inq',
#  'mo_sin_rcnt_rev_tl_op',
 'num_rev_accts',    #maybe
 'num_il_tl',        #maybe
#  'verification_status_Verified',
#  'total_acc',
 'mths_since_recent_bc',
#  'fico_range_high',
#  'libor',
 'total_rev_hi_lim', #maybe
 'total_bc_limit',   #maybe
#     
 'total_bal_ex_mort',
#  'loan_amnt',
 'bc_util',
#  'revol_util',
#  'annual_inc',
 'mo_sin_old_il_acct',
#  'bc_open_to_buy', 
#  'tot_cur_bal',
 'mo_sin_old_rev_tl_op',
 'avg_cur_bal',
#  'dti',
 'total_rec_int',
 'total_rec_late_fee',
#  'int_rate'
 'debt_settlement_flag',
 'collection_recovery_fee'
]

# %% [markdown]
# Use the above to drop features (i have shown some examples below) that are not helpful in prediction. These are features that we would not know prior to investing in a loan.
#
# Then we can recreate the model and train and test on that.

# %%
# df123

# %%
df123 = df123.drop(drop_vars, axis=1)
data=df123.copy().sample(n=50000, random_state=1)
numeric_features = data.select_dtypes(include=['int64', 'float64']).columns
categorical_features = data.select_dtypes(include=['object', 'category']).columns
categorical_features=categorical_features.drop(['loan_status'])
X = data.loc[:, data.columns != 'loan_status']
# Create a new dataframe y that includes only our 
y = data.loan_status

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
#from sklearn.impute import Imputer
from sklearn.compose import ColumnTransformer


#1 Inner Pipeline1: Create a numeric transformer with 2 steps
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy = 'median'))])

#2 Inner Pipeline2: Create a categorical transformer with 2 steps
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(drop='first'))])

#3 Create Preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.feature_selection import SelectFromModel, SelectKBest
from matplotlib import pyplot as plt
MainPipe = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(n_estimators=90) )])
#('fs',SelectFromModel(ExtraTreesClassifier())),
# split sample into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y,random_state=42)  # random_state=21 # stratify=y


# Fit Model
MainPipe.fit(X_train,y_train)

# Predict model
y_pred = MainPipe.predict(X_test)

# Output the accuracy of our prediction
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

# Visualize the confusion matrix to make it easier to read
from sklearn.metrics import confusion_matrix
con_matrix = confusion_matrix(y_test, y_pred)
confusion_matrix_df = pd.DataFrame(con_matrix, ('0', '1'), ('0', '1'))
heatmap = sns.heatmap(confusion_matrix_df, annot=True, annot_kws={"size": 20}, fmt="d", cmap="Blues")
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize = 14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize = 14)
plt.ylabel('Actual', fontsize = 14)
plt.xlabel('Predicted', fontsize = 14)

# Print the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# 0.7973333333333333
#               precision    recall  f1-score   support
#
#  Charged Off       0.59      0.07      0.13      3104
#   Fully Paid       0.80      0.99      0.89     11896
#
#     accuracy                           0.80     15000
#    macro avg       0.69      0.53      0.51     15000
# weighted avg       0.76      0.80      0.73     15000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a pd.Series of features importances
importances_rf = pd.Series(MainPipe.named_steps['classifier'].feature_importances_, index = pd.get_dummies(X,drop_first=True).drop(['home_ownership_NONE','purpose_educational'],axis=1).columns)

# Sort importances_rf
sorted_importances_rf = importances_rf.sort_values()

# Make a horizontal bar plot
plt.figure(figsize=(15,10))
sorted_importances_rf.plot(kind='barh', color='skyblue'); 
plt.show()

# %%
sorted_importances_rf.index.tolist()
# Out:
# ['home_ownership_MORTGAGE',
#  'out_prncp',
#  'num_tl_120dpd_2m',
#  'purpose_renewable_energy',
#  'sub_grade_G4',
#  'sub_grade_G3',
#  'sub_grade_G2',
#  'num_tl_30dpd',
#  'sub_grade_G1',
#  'sub_grade_F5',
#  'acc_now_delinq',
#  'disbursement_method_DirectPay',
#  'sub_grade_F3',
#  'purpose_house',
#  'sub_grade_F4',
#  'sub_grade_F1',
#  'sub_grade_F2',
#  'sub_grade_A2',
#  'purpose_vacation',
#  'purpose_wedding',
#  'delinq_amnt',
#  'chargeoff_within_12_mths',
#  'purpose_moving',
#  'sub_grade_A3',
#  'purpose_small_business',
#  'purpose_medical',
#  'purpose_major_purchase',
#  'sub_grade_A4',
#  'sub_grade_E3',
#  'sub_grade_E4',
#  'sub_grade_A5',
#  'sub_grade_D5',
#  'sub_grade_B1',
#  'sub_grade_E5',
#  'application_type_Joint App',
#  'sub_grade_B2',
#  'sub_grade_E1',
#  'sub_grade_E2',
#  'sub_grade_D4',
#  'collections_12_mths_ex_med',
#  'sub_grade_B3',
#  'emp_length_9 years',
#  'sub_grade_D3',
#  'sub_grade_C5',
#  'sub_grade_B4',
#  'sub_grade_D2',
#  'emp_length_8 years',
#  'sub_grade_C1',
#  'emp_length_6 years',
#  'sub_grade_B5',
#  'emp_length_7 years',
#  'sub_grade_D1',
#  'sub_grade_C4',
#  'purpose_home_improvement',
#  'purpose_other',
#  'sub_grade_C2',
#  'sub_grade_C3',
#  'emp_length_4 years',
#  'tax_liens',
#  'emp_length_5 years',
#  'emp_length_3 years',
#  'num_tl_90g_dpd_24m',
#  'home_ownership_OWN',
#  'emp_length_2 years',
#  'emp_length_< 1 year',
#  'purpose_credit_card',
#  'initial_list_status_w',
#  'pub_rec_bankruptcies',
#  'home_ownership_RENT',
#  'verification_status_Source Verified',
#  'purpose_debt_consolidation',
#  'sub_grade_G5',
#  'term_ 60 months',
#  'pub_rec',
#  'emp_length_10+ years',
#  'delinq_2yrs',
#  'num_accts_ever_120_pd',
#  'tot_coll_amt',
#  'inq_last_6mths',
#  'mort_acc',
#  'verification_status_Verified',
#  'num_tl_op_past_12m',
#  'percent_bc_gt_75',
#  'num_bc_sats',
#  'pct_tl_nvr_dlq',
#  'num_actv_rev_tl',
#  'num_bc_tl',
#  'fico_range_high',
#  'libor',
#  'mo_sin_rcnt_rev_tl_op',
#  'total_acc',
#  'loan_amnt',
#  'annual_inc',
#  'revol_util',
#  'bc_open_to_buy',
#  'tot_cur_bal',
#  'dti',
#  'int_rate']

# %%
df123.shape
# Out:
# (1117393, 44)

# %%
final_drop_vars = [
 'out_prncp', #dropping because 0 feature imporatnce
#  'home_ownership_MORTGAGE',
#  'purpose_renewable_energy',
 'num_tl_120dpd_2m',
#  'sub_grade_G3',
#  'sub_grade_G4',
#  'sub_grade_G2',
#  'sub_grade_G1',
 'num_tl_30dpd',
#  'sub_grade_F5',
#  'acc_now_delinq',
#  'disbursement_method_DirectPay',
#  'sub_grade_F3',
#  'sub_grade_F2',
#  'sub_grade_F4',
#  'purpose_wedding',
#  'purpose_house',
#  'sub_grade_F1',
#  'sub_grade_A2',
#  'purpose_vacation',
 'chargeoff_within_12_mths',         #dont think we have this but double check
#  'delinq_amnt',
#  'purpose_moving',
#  'purpose_small_business',
#  'sub_grade_E3',
#  'purpose_medical',
#  'sub_grade_E4',
#  'sub_grade_A3',
#  'purpose_major_purchase',
#  'sub_grade_A4',
#  'sub_grade_A5',
#  'sub_grade_E5',
#  'sub_grade_B1',
#  'sub_grade_E2',
#  'application_type_Joint App',
#  'sub_grade_D5',
#  'sub_grade_E1',
#  'sub_grade_B2',
#  'sub_grade_D4',
#  'collections_12_mths_ex_med',     #collections excluding medical
#  'sub_grade_B3',
#  'sub_grade_D2',
#  'emp_length_9 years',
#  'sub_grade_C5',
#  'sub_grade_D3',
#  'sub_grade_B4',
#  'emp_length_6 years',
#  'sub_grade_B5',
#  'emp_length_8 years',
#  'sub_grade_D1',
#  'emp_length_7 years',
#  'sub_grade_C1',
#  'sub_grade_C4',
#  'purpose_home_improvement',
#  'purpose_other',
#  'sub_grade_C2',
#  'sub_grade_C3',
 'tax_liens',                 #don think we have this, but check
#  'emp_length_5 years',
#  'emp_length_4 years',
#  'home_ownership_OWN',
#  'emp_length_3 years',
#  'emp_length_2 years',
#  'num_tl_90g_dpd_24m',
#  'emp_length_< 1 year',
#  'initial_list_status_w',
#  'purpose_credit_card',
#  'pub_rec_bankruptcies',    #can we click on 'num public records' and see this?
#  'home_ownership_RENT',
#  'verification_status_Source Verified',
#  'purpose_debt_consolidation',
#  'sub_grade_G5',
#  'term_ 60 months',
#  'emp_length_10+ years',
#  'pub_rec',
#  'delinq_2yrs',
 'num_accts_ever_120_pd',
 'tot_coll_amt',               #we only have "total collections excluding medical" (listed above)
#  'inq_last_6mths',
#  'mort_acc',
 'num_tl_op_past_12m',
#  'percent_bc_gt_75',
 'num_bc_sats',                #maybe keep?
#  'pct_tl_nvr_dlq',
 'num_actv_rev_tl',
 'num_bc_tl',
    
    #already checked above
#  'verification_status_Verified',
#  'fico_range_high',
#  'libor',
#  'mo_sin_rcnt_rev_tl_op',
#  'total_acc',
#  'loan_amnt',
#  'annual_inc',
#  'revol_util',
#  'tot_cur_bal',
#  'bc_open_to_buy',
#  'dti',
#  'int_rate'
]

# %%
#final removal

df123 = df123.drop(final_drop_vars, axis=1)
data=df123.copy().sample(n=50000, random_state=1)
numeric_features = data.select_dtypes(include=['int64', 'float64']).columns
categorical_features = data.select_dtypes(include=['object', 'category']).columns
categorical_features=categorical_features.drop(['loan_status'])
X = data.loc[:, data.columns != 'loan_status']
# Create a new dataframe y that includes only our 
y = data.loan_status

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
#from sklearn.impute import Imputer
from sklearn.compose import ColumnTransformer


#1 Inner Pipeline1: Create a numeric transformer with 2 steps
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy = 'median'))])

#2 Inner Pipeline2: Create a categorical transformer with 2 steps
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(drop='first'))])

#3 Create Preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.feature_selection import SelectFromModel, SelectKBest
from matplotlib import pyplot as plt
MainPipe = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(n_estimators=90) )])
#('fs',SelectFromModel(ExtraTreesClassifier())),
# split sample into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y,random_state=42)  # random_state=21 # stratify=y


# Fit Model
MainPipe.fit(X_train,y_train)

# Predict model
y_pred = MainPipe.predict(X_test)

# Output the accuracy of our prediction
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

# Visualize the confusion matrix to make it easier to read
from sklearn.metrics import confusion_matrix
con_matrix = confusion_matrix(y_test, y_pred)
confusion_matrix_df = pd.DataFrame(con_matrix, ('0', '1'), ('0', '1'))
heatmap = sns.heatmap(confusion_matrix_df, annot=True, annot_kws={"size": 20}, fmt="d", cmap="Blues")
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize = 14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize = 14)
plt.ylabel('Actual', fontsize = 14)
plt.xlabel('Predicted', fontsize = 14)

# Print the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# 0.7954
#               precision    recall  f1-score   support
#
#  Charged Off       0.54      0.08      0.14      3104
#   Fully Paid       0.80      0.98      0.88     11896
#
#     accuracy                           0.80     15000
#    macro avg       0.67      0.53      0.51     15000
# weighted avg       0.75      0.80      0.73     15000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a pd.Series of features importances
importances_rf = pd.Series(MainPipe.named_steps['classifier'].feature_importances_, index = pd.get_dummies(X,drop_first=True).drop(['home_ownership_NONE','purpose_educational'],axis=1).columns)

# Sort importances_rf
sorted_importances_rf = importances_rf.sort_values()

# Make a horizontal bar plot
plt.figure(figsize=(25,20))
sorted_importances_rf.plot(kind='barh', color='skyblue'); 
plt.show()

# %%
sorted_importances_rf
# Out:
# home_ownership_MORTGAGE                8.909854e-07
# purpose_renewable_energy               1.410411e-04
# sub_grade_G3                           2.899855e-04
# sub_grade_G4                           3.071523e-04
# sub_grade_G2                           3.760779e-04
# sub_grade_G1                           4.130587e-04
# sub_grade_F5                           4.937114e-04
# disbursement_method_DirectPay          6.130808e-04
# acc_now_delinq                         6.938944e-04
# sub_grade_F3                           7.989850e-04
# sub_grade_F2                           8.898026e-04
# sub_grade_F1                           9.069641e-04
# sub_grade_F4                           9.239990e-04
# purpose_house                          9.817878e-04
# sub_grade_A2                           1.030310e-03
# purpose_wedding                        1.069853e-03
# purpose_vacation                       1.077933e-03
# delinq_amnt                            1.230914e-03
# purpose_moving                         1.330837e-03
# sub_grade_A3                           1.708172e-03
# purpose_small_business                 1.752390e-03
# purpose_medical                        1.815585e-03
# sub_grade_E3                           1.830113e-03
# sub_grade_A4                           1.952860e-03
# sub_grade_E4                           2.015046e-03
# purpose_major_purchase                 2.219150e-03
# sub_grade_B1                           2.257072e-03
# sub_grade_D5                           2.260432e-03
# sub_grade_E5                           2.268678e-03
# sub_grade_A5                           2.297020e-03
#                                            ...
# num_tl_90g_dpd_24m                     5.696098e-03
# emp_length_< 1 year                    5.766214e-03
# home_ownership_OWN                     5.838372e-03
# initial_list_status_w                  6.829001e-03
# purpose_credit_card                    7.410417e-03
# home_ownership_RENT                    7.528622e-03
# pub_rec_bankruptcies                   7.715490e-03
# verification_status_Source Verified    8.505857e-03
# purpose_debt_consolidation             9.398640e-03
# sub_grade_G5                           9.531213e-03
# emp_length_10+ years                   9.896006e-03
# term_ 60 months                        1.003075e-02
# pub_rec                                1.076569e-02
# delinq_2yrs                            1.273795e-02
# inq_last_6mths                         1.918573e-02
# verification_status_Verified           2.155405e-02
# mort_acc                               2.344288e-02
# percent_bc_gt_75                       3.332734e-02
# pct_tl_nvr_dlq                         3.569660e-02
# fico_range_high                        4.293681e-02
# libor                                  4.294081e-02
# mo_sin_rcnt_rev_tl_op                  4.722365e-02
# total_acc                              5.000184e-02
# loan_amnt                              5.301096e-02
# annual_inc                             5.600263e-02
# revol_util                             5.779572e-02
# tot_cur_bal                            5.981717e-02
# bc_open_to_buy                         6.111356e-02
# dti                                    6.368200e-02
# int_rate                               7.901042e-02
# Length: 87, dtype: float64

# %% [markdown]
# # Sub Grade Chart

# %%
df_sub_grade = df123[['sub_grade', 'loan_status']]
data=df_sub_grade.copy().sample(n=50000, random_state=1)
numeric_features = data.select_dtypes(include=['int64', 'float64']).columns
categorical_features = data.select_dtypes(include=['object', 'category']).columns
categorical_features=categorical_features.drop(['loan_status'])
X = data.loc[:, data.columns != 'loan_status']
# Create a new dataframe y that includes only our 
y = data.loan_status

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
#from sklearn.impute import Imputer
from sklearn.compose import ColumnTransformer


#1 Inner Pipeline1: Create a numeric transformer with 2 steps
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy = 'median'))])

#2 Inner Pipeline2: Create a categorical transformer with 2 steps
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(drop='first'))])

#3 Create Preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.feature_selection import SelectFromModel, SelectKBest
from matplotlib import pyplot as plt
MainPipe = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(n_estimators=90) )])
#('fs',SelectFromModel(ExtraTreesClassifier())),
# split sample into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y,random_state=42)  # random_state=21 # stratify=y


# Fit Model
MainPipe.fit(X_train,y_train)

# Predict model
y_pred = MainPipe.predict(X_test)

# Output the accuracy of our prediction
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

# Visualize the confusion matrix to make it easier to read
from sklearn.metrics import confusion_matrix
con_matrix = confusion_matrix(y_test, y_pred)
confusion_matrix_df = pd.DataFrame(con_matrix, ('0', '1'), ('0', '1'))
heatmap = sns.heatmap(confusion_matrix_df, annot=True, annot_kws={"size": 20}, fmt="d", cmap="Blues")
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize = 14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize = 14)
plt.ylabel('Actual', fontsize = 14)
plt.xlabel('Predicted', fontsize = 14)

# Print the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# 0.7918
#               precision    recall  f1-score   support
#
#  Charged Off       0.45      0.03      0.05      3104
#   Fully Paid       0.80      0.99      0.88     11896
#
#     accuracy                           0.79     15000
#    macro avg       0.62      0.51      0.47     15000
# weighted avg       0.72      0.79      0.71     15000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a pd.Series of features importances
importances_rf = pd.Series(MainPipe.named_steps['classifier'].feature_importances_, index = pd.get_dummies(X,drop_first=True).columns)

# Sort importances_rf
sorted_importances_rf = importances_rf.sort_values()

# Make a horizontal bar plot
plt.figure(figsize=(15,10))
sorted_importances_rf.plot(kind='barh', color='skyblue'); 
plt.show()

# %% [markdown]
# # Other Features

# %%
df_other_features = df123.drop(['sub_grade'], axis=1)
data=df_other_features.copy().sample(n=50000, random_state=1)

numeric_features = data.select_dtypes(include=['int64', 'float64']).columns
categorical_features = data.select_dtypes(include=['object', 'category']).columns
categorical_features=categorical_features.drop(['loan_status'])
X = data.loc[:, data.columns != 'loan_status']
# Create a new dataframe y that includes only our 
y = data.loan_status

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
#from sklearn.impute import Imputer
from sklearn.compose import ColumnTransformer


#1 Inner Pipeline1: Create a numeric transformer with 2 steps
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy = 'median'))])

#2 Inner Pipeline2: Create a categorical transformer with 2 steps
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(drop='first'))])

#3 Create Preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.feature_selection import SelectFromModel, SelectKBest
from matplotlib import pyplot as plt
MainPipe = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(n_estimators=90) )])
#('fs',SelectFromModel(ExtraTreesClassifier())),
# split sample into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y,random_state=42)  # random_state=21 # stratify=y


# Fit Model
MainPipe.fit(X_train,y_train)

# Predict model
y_pred = MainPipe.predict(X_test)

# Output the accuracy of our prediction
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

# Visualize the confusion matrix to make it easier to read
from sklearn.metrics import confusion_matrix
con_matrix = confusion_matrix(y_test, y_pred)
confusion_matrix_df = pd.DataFrame(con_matrix, ('0', '1'), ('0', '1'))
heatmap = sns.heatmap(confusion_matrix_df, annot=True, annot_kws={"size": 20}, fmt="d", cmap="Blues")
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize = 14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize = 14)
plt.ylabel('Actual', fontsize = 14)
plt.xlabel('Predicted', fontsize = 14)

# Print the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# 0.7966666666666666
#               precision    recall  f1-score   support
#
#  Charged Off       0.56      0.08      0.13      3104
#   Fully Paid       0.80      0.98      0.88     11896
#
#     accuracy                           0.80     15000
#    macro avg       0.68      0.53      0.51     15000
# weighted avg       0.75      0.80      0.73     15000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a pd.Series of features importances
importances_rf = pd.Series(MainPipe.named_steps['classifier'].feature_importances_, index = pd.get_dummies(X,drop_first=True).drop(['home_ownership_NONE','purpose_educational'],axis=1).columns)

# Sort importances_rf
sorted_importances_rf = importances_rf.sort_values()

# Make a horizontal bar plot
plt.figure(figsize=(15,10))
sorted_importances_rf.plot(kind='barh', color='skyblue'); 
plt.show()

# %% [markdown]
# # Final Tuning of First Model

# %%
# print(sorted_importances_rf)
drop = sorted_importances_rf[sorted_importances_rf > 0.01]
drop = drop.index.tolist()
drop
# Out:
# ['term_ 60 months',
#  'emp_length_10+ years',
#  'pub_rec',
#  'delinq_2yrs',
#  'inq_last_6mths',
#  'verification_status_Verified',
#  'mort_acc',
#  'percent_bc_gt_75',
#  'pct_tl_nvr_dlq',
#  'fico_range_high',
#  'libor',
#  'mo_sin_rcnt_rev_tl_op',
#  'total_acc',
#  'loan_amnt',
#  'annual_inc',
#  'revol_util',
#  'bc_open_to_buy',
#  'tot_cur_bal',
#  'dti',
#  'int_rate']

# %%
final_vars = ['loan_status',
             
              # x vars
             'term',
             'emp_length',
             'pub_rec',
             'delinq_2yrs',
             'inq_last_6mths',
             'verification_status',
             'mort_acc',
             'percent_bc_gt_75',
             'pct_tl_nvr_dlq',
             'fico_range_high',
             'libor',
             'mo_sin_rcnt_rev_tl_op',
             'total_acc',
             'loan_amnt',
             'annual_inc',
             'revol_util',
             'bc_open_to_buy',
             'tot_cur_bal',
             'dti',
             'int_rate',
             'sub_grade']
# df_final = df123[[final_vars]]

# %%
df123.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1117393 entries, 0 to 1117392
# Data columns (total 33 columns):
# emp_length                    1047842 non-null category
# percent_bc_gt_75              1104650 non-null float64
# bc_open_to_buy                1105059 non-null float64
# revol_util                    1116711 non-null float64
# dti                           1117019 non-null float64
# policy_code                   1117393 non-null category
# pub_rec                       1117393 non-null float64
# pub_rec_bankruptcies          1117393 non-null float64
# purpose                       1117393 non-null category
# acc_now_delinq                1117393 non-null float64
# sub_grade                     1117393 non-null category
# verification_status           1117393 non-null category
# term                          1117393 non-null category
# total_acc                     1117393 non-null float64
# tot_cur_bal                   1117393 non-null float64
# pct_tl_nvr_dlq                1117392 non-null float64
# inq_last_6mths                1117392 non-null float64
# initial_list_status           1117393 non-null category
# home_ownership                1117393 non-null category
# fico_range_high               1117393 non-null float64
# disbursement_method           1117393 non-null category
# delinq_amnt                   1117393 non-null float64
# delinq_2yrs                   1117393 non-null float64
# collections_12_mths_ex_med    1117393 non-null float64
# application_type              1117393 non-null category
# annual_inc                    1117393 non-null float64
# int_rate                      1117393 non-null float64
# num_tl_90g_dpd_24m            1117393 non-null float64
# mort_acc                      1117393 non-null float64
# mo_sin_rcnt_rev_tl_op         1117393 non-null float64
# loan_status                   1117393 non-null category
# loan_amnt                     1117393 non-null float64
# libor                         1117393 non-null float64
# dtypes: category(11), float64(22)
# memory usage: 207.8 MB

# %%
df_final = df123[final_vars]
# df_final = df_final.loan_status[df_final.loan_status !='Default']
data=df_final.copy()#.sample(n=200000, random_state=1)
# data = data.drop(data[data.loan_status=='Default'].index)
data.drop(data[data.loan_status=='Default'].index, inplace=True)

numeric_features = data.select_dtypes(include=['int64', 'float64']).columns
categorical_features = data.select_dtypes(include=['object', 'category']).columns
categorical_features=categorical_features.drop(['loan_status'])
X = data.loc[:, data.columns != 'loan_status']
# Create a new dataframe y that includes only our 
y = data.loan_status
y.value_counts()
# Out:
# Fully Paid     884132
# Charged Off    233221
# Default             0
# Name: loan_status, dtype: int64

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
#from sklearn.impute import Imputer
from sklearn.compose import ColumnTransformer


#1 Inner Pipeline1: Create a numeric transformer with 2 steps
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy = 'median'))])

#2 Inner Pipeline2: Create a categorical transformer with 2 steps
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(drop='first'))])

#3 Create Preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.feature_selection import SelectFromModel, SelectKBest
from matplotlib import pyplot as plt
MainPipe = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(n_estimators=90) )])
#('fs',SelectFromModel(ExtraTreesClassifier())),
# split sample into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y,random_state=42)  # random_state=21 # stratify=y


# Fit Model
MainPipe.fit(X_train,y_train)

# Predict model
y_pred = MainPipe.predict(X_test)

# Output the accuracy of our prediction
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

# Visualize the confusion matrix to make it easier to read
from sklearn.metrics import confusion_matrix
con_matrix = confusion_matrix(y_test, y_pred)
confusion_matrix_df = pd.DataFrame(con_matrix, ('0', '1'), ('0', '1'))
heatmap = sns.heatmap(confusion_matrix_df, annot=True, annot_kws={"size": 20}, fmt="d", cmap="Blues")
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize = 14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize = 14)
plt.ylabel('Actual', fontsize = 14)
plt.xlabel('Predicted', fontsize = 14)

# Print the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# 0.7944279040351306
#               precision    recall  f1-score   support
#
#  Charged Off       0.54      0.11      0.18     69966
#   Fully Paid       0.81      0.98      0.88    265240
#
#     accuracy                           0.79    335206
#    macro avg       0.67      0.54      0.53    335206
# weighted avg       0.75      0.79      0.74    335206

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a pd.Series of features importances
importances_rf = pd.Series(MainPipe.named_steps['classifier'].feature_importances_, index = pd.get_dummies(X,drop_first=True).columns)

# Sort importances_rf
sorted_importances_rf = importances_rf.sort_values()

# Make a horizontal bar plot
plt.figure(figsize=(15,10))
sorted_importances_rf.plot(kind='barh', color='skyblue'); 
plt.show()

# %% [markdown]
# # Next Steps

# %% [markdown]
# - model currently is around 79% accurate
#     - need to figure out if we want to drop more of these and if that will improve accuracy?
#     - test on a bigger subset? (currently only testing on 50k)
#     - use more estimators (currently only using 90)
# - return model
#     - using same dataset, build a model that predicts return
#     - in the article (https://www.liebertpub.com/doi/full/10.1089/big.2018.0092) it describes how to do that in the end
# - combination model
#     - also in the article
#     - need to make a combined model that accounts for both chance of defaulting and maximizing return
# - end goal for notebook
#     - to compare each model against a "random investment strategy" to show that our combination model (hopefully) is the best of the 4
#     - maybe by coparing AUC as well as running simulations? not sure how to do this
#     - clean up redundant code, and add in chart formatting throughout so the notebook looks professtional when we submit it
